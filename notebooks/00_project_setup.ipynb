# %% [markdown]
# # Project Setup\n\nLoad the Zillow-derived dataset and preview the portfolio inputs.

# %%
from pathlib import Path
import sys

sys.path.append(str(Path('..').resolve() / 'src'))

from portfolio_opt.data import DataConfig, load_raw_csv, prepare_portfolio_data

df_raw = load_raw_csv('../data/raw/quartile_update_costs.csv')
df = prepare_portfolio_data(df_raw, DataConfig(rehab_cost_col='Rehab Costs'))
df.head()
